# %% [markdown]
# # APIM ❤️ OpenAI
#
# ## Prompt flow lab
# ![flow](../../images/prompt-flow.gif)
#
# Playground to try the [Azure AI Studio Prompt Flow](https://learn.microsoft.com/en-us/azure/ai-studio/how-to/prompt-flow) with Azure API Management. The Prompt Flow OpenAI connection will be facilitated by APIM, enabling load balancing, token counting, and other features. The Prompt Flow will run in an Azure Container App and will be accessed through APIM.
#
# Prompt flow is a development tool designed to streamline the entire development cycle of AI applications powered by Large Language Models (LLMs). Prompt flow provides a comprehensive solution that simplifies the process of prototyping, experimenting, iterating, and deploying your AI applications.
# Prompt flow is available independently as an open-source project on [GitHub](https://github.com/microsoft/promptflow).
#
# ### Result
# ![result](result.png)
#
# ### TOC
# - [0️⃣ Initialize notebook variables](#0)
# - [1️⃣ Create the Azure Resource Group](#1)
# - [2️⃣ Create deployment using 🦾 Bicep](#2)
# - [3️⃣ Get the deployment outputs](#3)
# - [4️⃣ Enable Prompt Flow tracing (optional)](#4)
# - [5️⃣ Update the connection with APIM Gateway URL and APIM Subscription Key](#5)
# - [🧪 Test the Flow locally](#localtest)
# - [6️⃣ Create the Flow in the AI Studio Project (optional)](#6)
# - [7️⃣ Build the Flow in the Docker format](#7)
# - [8️⃣ Deploy the Flow to an Azure Container App](#8)
# - [🧪 Test the Flow through APIM](#requests)
# - [🔍 Analyze Application Insights requests](#portal)
# - [🗑️ Clean up resources](#clean)
#
# ### Prerequisites
# - [Python 3.8 or later version](https://www.python.org/) installed
# - [Prompt flow](https://microsoft.github.io/promptflow/how-to-guides/installation/index.html#install-prompt-flow) installed
# - [VS Code](https://code.visualstudio.com/) installed with the [Jupyter notebook extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) enabled
# - [Azure CLI](https://learn.microsoft.com/en-us/cli/azure/install-azure-cli) installed
# - [An Azure Subscription](https://azure.microsoft.com/en-us/free/) with Contributor permissions
# - [Access granted to Azure OpenAI](https://aka.ms/oai/access)
# - [Sign in to Azure with Azure CLI](https://learn.microsoft.com/en-us/cli/azure/authenticate-azure-cli-interactively)

# %% [markdown]
# <a id='0'></a>
# ### 0️⃣ Initialize notebook variables
#
# - Resources will be suffixed by a unique string based on your subscription id
# - Adjust the location parameters according your preferences and on the [product availability by Azure region.](https://azure.microsoft.com/en-us/explore/global-infrastructure/products-by-region/?cdn=disable&products=cognitive-services,api-management)
# - Adjust the OpenAI model and version according the [availability by region.](https://learn.microsoft.com/en-us/azure/ai-services/openai/concepts/models)

# %%
import os
import json
import datetime
import requests

lab_prefix="aip-pevo2-"
tool_prefix="st-pevo1-"
deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
resource_group_name = f"{lab_prefix}{deployment_name}" # change the name to match your naming style

resource_group_location = "westeurope"
apim_resource_name = "apim"
apim_resource_location = "westeurope"
#apim_resource_sku = "Basicv2"
apim_resource_sku = "Consumption" 


openai_resources = [ {"name": "openai1", "location": "swedencentral"}, {"name": "openai2", "location": "francecentral"} ] # list of OpenAI resources to deploy. Clear this list to use only the mock resources
openai_resources_sku = "S0"
openai_model_name = "gpt-35-turbo"
openai_model_version = "0613"
openai_deployment_name = "gpt-35-turbo"
openai_api_version = "2024-02-01"
openai_specification_url='https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/' + openai_api_version + '/inference.json'
openai_backend_pool = "openai-backend-pool"
mock_backend_pool = "mock-backend-pool"
mock_webapps = [ ]

log_analytics_name = "workspace"
app_insights_name = 'insights'

ai_studio_hub_name = 'hub'
ai_studio_project_name = 'project'
storage_account_name = 'storage'
keyvault_name = 'keyvault'
container_registry_name = 'registry'

containerapp_env_name = 'acaenv'
containerapp_name = 'aca'

flow_name = 'basic-chat' # the local folder must have the same name
print("✅ Set Variables done ⌚ ", datetime.datetime.now().isoformat())
# Out:
# ✅ Set Variables done ⌚  2024-10-25T23:27:00.270777

# %% [markdown]
# <a id='1'></a>
# ### 1️⃣ Create the Azure Resource Group
# All resources deployed in this lab will be created in the specified resource group. Skip this step if you want to use an existing resource group.

# %%
resource_group_stdout = ! az group create --name {resource_group_name} --location {resource_group_location}
if resource_group_stdout.n.startswith("ERROR"):
    print(resource_group_stdout)
else:
    print("✅ Azure Resource Group ", resource_group_name, " created ⌚ ", datetime.datetime.now().time())
# Out:
# ✅ Azure Resource Group  aip-pevo2-prompt-flow  created ⌚  23:27:09.425738

# %% [markdown]
# <a id='2'></a>
# ### 2️⃣ Create deployment using 🦾 Bicep
#
# This lab uses [Bicep](https://learn.microsoft.com/en-us/azure/azure-resource-manager/bicep/overview?tabs=bicep) to declarative define all the resources that will be deployed. Change the parameters or the [main.bicep](main.bicep) directly to try different configurations.

# %%
if len(openai_resources) > 0:
    backend_id = openai_backend_pool if len(openai_resources) > 1 else openai_resources[0].get("name")

with open("policy.xml", 'r') as policy_xml_file:
    policy_template_xml = policy_xml_file.read()
    policy_xml = policy_template_xml.replace("{backend-id}", backend_id)
    policy_xml_file.close()
open("policy.xml", 'w').write(policy_xml)

bicep_parameters = {
  "$schema": "https://schema.management.azure.com/schemas/2019-04-01/deploymentParameters.json#",
  "contentVersion": "1.0.0.0",
  "parameters": {
    "mockWebApps": { "value": mock_webapps },
    "mockBackendPoolName": { "value": mock_backend_pool },
    "openAIBackendPoolName": { "value": openai_backend_pool },
    "openAIConfig": { "value": openai_resources },
    "openAIDeploymentName": { "value": openai_deployment_name },
    "openAISku": { "value": openai_resources_sku },
    "openAIModelName": { "value": openai_model_name },
    "openAIModelVersion": { "value": openai_model_version },
    "openAIAPISpecURL": { "value": openai_specification_url },
    "apimResourceName": { "value": apim_resource_name},
    "apimResourceLocation": { "value": apim_resource_location},
    "apimSku": { "value": apim_resource_sku},
    "logAnalyticsName": { "value": log_analytics_name },
    "applicationInsightsName": { "value": app_insights_name },
    "aiStudioHubName": { "value": ai_studio_hub_name },
    "aiStudioProjectName": { "value": ai_studio_project_name },
    "storageAccountName": { "value": storage_account_name }, 
    "keyVaultName": { "value": keyvault_name },
    "containerRegistryName": { "value": container_registry_name },
    "containerAppEnvName": { "value": containerapp_env_name },
    "containerAppName": { "value": containerapp_name },
    "flowName": { "value": flow_name }
  }
}
with open('params.json', 'w') as bicep_parameters_file:
    bicep_parameters_file.write(json.dumps(bicep_parameters))

! az deployment group create --name {deployment_name} --resource-group {resource_group_name} --template-file "main.bicep" --parameters "params.json"

open("policy.xml", 'w').write(policy_template_xml)

print("✅ bicep based deployment done ⌚ ", datetime.datetime.now().isoformat())
# Out:
# /home/per/azdevops/pevosdcgm/AI-Gateway/labs/prompt-flow/main.bicep(323,3) : Warning BCP035: The specified "object" declaration is missing the following required properties: "protocol", "url". If this is a resource type definition inaccuracy, report it using https://aka.ms/bicep-type-issues. [https://aka.ms/bicep/core-diagnostics#BCP035]
# /home/per/azdevops/pevosdcgm/AI-Gateway/labs/prompt-flow/main.bicep(340,3) : Warning BCP035: The specified "object" declaration is missing the following required properties: "protocol", "url". If this is a resource type definition inaccuracy, report it using https://aka.ms/bicep-type-issues. [https://aka.ms/bicep/core-diagnostics#BCP035]
# /home/per/azdevops/pevosdcgm/AI-Gateway/labs/prompt-flow/main.bicep(405,5) : Warning BCP037: The property "CustomMetricsOptedInType" is not allowed on objects of type "ApplicationInsightsComponentProperties". Permissible properties include "DisableIpMasking", "DisableLocalAuth", "Flow_Type", "ForceCustomerStorageForProfiler", "HockeyAppId", "ImmediatePurgeDataOn30Days", "IngestionMode", "publicNetworkAccessForIngestion", "publicNetworkAccessForQuery", "Request_Source", "RetentionInDays", "SamplingPercentage". If this is a resource type definition inaccuracy, report it using https://aka.ms/bicep-type-issues. [https://aka.ms/bicep/core-diagnostics#BCP037]
# /home/per/azdevops/pevosdcgm/AI-Gateway/labs/prompt-flow/main.bicep(686,7) : Warning BCP037: The property "enforceAccessToDefaultSecretStores" is not allowed on objects of type "ApiKey". Permissible properties include "expiryTime", "sharedUserList". If this is a resource type definition inaccuracy, report it using https://aka.ms/bicep-type-issues. [https://aka.ms/bicep/core-diagnostics#BCP037]
# /home/per/azdevops/pevosdcgm/AI-Gateway/labs/prompt-flow/main.bicep(739,12) : Warning BCP036: The property "value" expected a value of type "null | string" but the provided value is of type "object". If this is a resource type definition inaccuracy, report it using https://aka.ms/bicep-type-issues. [https://aka.ms/bicep/core-diagnostics#BCP036]
#
# {| Finished .. - Starting ..
#   "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Resources/deployments/prompt-flow",
#   "location": null,
#   "name": "prompt-flow",
#   "properties": {
#     "correlationId": "43629e26-2e25-43b1-bd62-d040c878343f",
#     "debugSetting": null,
#     "dependencies": [
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/blobServices/default",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "storagerzyeftgva7kgm/default",
#             "resourceType": "Microsoft.Storage/storageAccounts/blobServices"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/blobServices/default/containers/default",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "storagerzyeftgva7kgm/default/default",
#         "resourceType": "Microsoft.Storage/storageAccounts/blobServices/containers"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/queueServices/default",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "storagerzyeftgva7kgm/default",
#             "resourceType": "Microsoft.Storage/storageAccounts/queueServices"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/queueServices/default/queues/default",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "storagerzyeftgva7kgm/default/default",
#         "resourceType": "Microsoft.Storage/storageAccounts/queueServices/queues"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "storagerzyeftgva7kgm",
#             "resourceType": "Microsoft.Storage/storageAccounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/blobServices/default",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "storagerzyeftgva7kgm/default",
#         "resourceType": "Microsoft.Storage/storageAccounts/blobServices"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "storagerzyeftgva7kgm",
#             "resourceType": "Microsoft.Storage/storageAccounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/fileServices/default",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "storagerzyeftgva7kgm/default",
#         "resourceType": "Microsoft.Storage/storageAccounts/fileServices"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "storagerzyeftgva7kgm",
#             "resourceType": "Microsoft.Storage/storageAccounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/queueServices/default",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "storagerzyeftgva7kgm/default",
#         "resourceType": "Microsoft.Storage/storageAccounts/queueServices"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "storagerzyeftgva7kgm",
#             "resourceType": "Microsoft.Storage/storageAccounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/tableServices/default",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "storagerzyeftgva7kgm/default",
#         "resourceType": "Microsoft.Storage/storageAccounts/tableServices"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/subscriptions/openai-subscription",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/openai-subscription",
#             "resourceType": "Microsoft.ApiManagement/service/subscriptions"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/hub-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "hub-rzyeftgva7kgm",
#             "resourceType": "Microsoft.MachineLearningServices/workspaces"
#           },
#           {
#             "apiVersion": "2023-05-01-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "actionName": "listSecrets",
#             "apiVersion": "2023-05-01-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/subscriptions/openai-subscription",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/openai-subscription",
#             "resourceType": "Microsoft.ApiManagement/service/subscriptions"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/hub-rzyeftgva7kgm/connections/open_ai_connection",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "hub-rzyeftgva7kgm/open_ai_connection",
#         "resourceType": "Microsoft.MachineLearningServices/workspaces/connections"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/openai",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "apim-rzyeftgva7kgm/openai",
#         "resourceType": "Microsoft.ApiManagement/service/apis"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/openai",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/openai/policies/policy",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "apim-rzyeftgva7kgm/openai/policy",
#         "resourceType": "Microsoft.ApiManagement/service/apis/policies"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/backends/openai1",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/openai1",
#             "resourceType": "Microsoft.ApiManagement/service/backends"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/backends/openai2",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/openai2",
#             "resourceType": "Microsoft.ApiManagement/service/backends"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/backends/openai-backend-pool",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "apim-rzyeftgva7kgm/openai-backend-pool",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/subscriptions/openai-subscription",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "apim-rzyeftgva7kgm/openai-subscription",
#         "resourceType": "Microsoft.ApiManagement/service/subscriptions"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.OperationalInsights/workspaces/workspace-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "workspace-rzyeftgva7kgm",
#             "resourceType": "Microsoft.OperationalInsights/workspaces"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Insights/components/insights-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "insights-rzyeftgva7kgm",
#         "resourceType": "Microsoft.Insights/components"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Insights/components/insights-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "insights-rzyeftgva7kgm",
#             "resourceType": "Microsoft.Insights/components"
#           },
#           {
#             "apiVersion": "2020-02-02",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Insights/components/insights-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "insights-rzyeftgva7kgm",
#             "resourceType": "Microsoft.Insights/components"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/loggers/apim-logger",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "apim-rzyeftgva7kgm/apim-logger",
#         "resourceType": "Microsoft.ApiManagement/service/loggers"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/openai",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/loggers/apim-logger",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/apim-logger",
#             "resourceType": "Microsoft.ApiManagement/service/loggers"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/openai/diagnostics/applicationinsights",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "apim-rzyeftgva7kgm/openai/applicationinsights",
#         "resourceType": "Microsoft.ApiManagement/service/apis/diagnostics"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/hub-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "hub-rzyeftgva7kgm",
#             "resourceType": "Microsoft.MachineLearningServices/workspaces"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.KeyVault/vaults/keyvault-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "keyvault-rzyeftgva7kgm",
#             "resourceType": "Microsoft.KeyVault/vaults"
#           },
#           {
#             "apiVersion": "2024-01-01-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/hub-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "hub-rzyeftgva7kgm",
#             "resourceType": "Microsoft.MachineLearningServices/workspaces"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.KeyVault/vaults/keyvault-rzyeftgva7kgm/accessPolicies/add",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "keyvault-rzyeftgva7kgm/add",
#         "resourceType": "Microsoft.KeyVault/vaults/accessPolicies"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Insights/components/insights-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "insights-rzyeftgva7kgm",
#             "resourceType": "Microsoft.Insights/components"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ContainerRegistry/registries/registryrzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "registryrzyeftgva7kgm",
#             "resourceType": "Microsoft.ContainerRegistry/registries"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.KeyVault/vaults/keyvault-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "keyvault-rzyeftgva7kgm",
#             "resourceType": "Microsoft.KeyVault/vaults"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "storagerzyeftgva7kgm",
#             "resourceType": "Microsoft.Storage/storageAccounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/hub-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "hub-rzyeftgva7kgm",
#         "resourceType": "Microsoft.MachineLearningServices/workspaces"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/hub-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "hub-rzyeftgva7kgm",
#             "resourceType": "Microsoft.MachineLearningServices/workspaces"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/project-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "project-rzyeftgva7kgm",
#         "resourceType": "Microsoft.MachineLearningServices/workspaces"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.App/containerApps/aca-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "aca-rzyeftgva7kgm",
#             "resourceType": "Microsoft.App/containerApps"
#           },
#           {
#             "apiVersion": "2023-11-02-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.App/containerApps/aca-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "aca-rzyeftgva7kgm",
#             "resourceType": "Microsoft.App/containerApps"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/basic-chat",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "apim-rzyeftgva7kgm/basic-chat",
#         "resourceType": "Microsoft.ApiManagement/service/apis"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/loggers/apim-logger",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/apim-logger",
#             "resourceType": "Microsoft.ApiManagement/service/loggers"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/basic-chat",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/basic-chat",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/basic-chat/diagnostics/applicationinsights",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "apim-rzyeftgva7kgm/basic-chat/applicationinsights",
#         "resourceType": "Microsoft.ApiManagement/service/apis/diagnostics"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.OperationalInsights/workspaces/workspace-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "workspace-rzyeftgva7kgm",
#             "resourceType": "Microsoft.OperationalInsights/workspaces"
#           },
#           {
#             "apiVersion": "2021-12-01-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.OperationalInsights/workspaces/workspace-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "workspace-rzyeftgva7kgm",
#             "resourceType": "Microsoft.OperationalInsights/workspaces"
#           },
#           {
#             "actionName": "listKeys",
#             "apiVersion": "2021-12-01-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.OperationalInsights/workspaces/workspace-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "workspace-rzyeftgva7kgm",
#             "resourceType": "Microsoft.OperationalInsights/workspaces"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.App/managedEnvironments/acaenv-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "acaenv-rzyeftgva7kgm",
#         "resourceType": "Microsoft.App/managedEnvironments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ManagedIdentity/userAssignedIdentities/aca-mi-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "aca-mi-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ManagedIdentity/userAssignedIdentities"
#           },
#           {
#             "apiVersion": "2022-01-31-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ManagedIdentity/userAssignedIdentities/aca-mi-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "aca-mi-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ManagedIdentity/userAssignedIdentities"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Authorization/roleAssignments/68fc0112-cea1-54ee-b8d2-df0df6727501",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "68fc0112-cea1-54ee-b8d2-df0df6727501",
#         "resourceType": "Microsoft.Authorization/roleAssignments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/subscriptions/openai-subscription",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/openai-subscription",
#             "resourceType": "Microsoft.ApiManagement/service/subscriptions"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Insights/components/insights-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "insights-rzyeftgva7kgm",
#             "resourceType": "Microsoft.Insights/components"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.App/managedEnvironments/acaenv-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "acaenv-rzyeftgva7kgm",
#             "resourceType": "Microsoft.App/managedEnvironments"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ManagedIdentity/userAssignedIdentities/aca-mi-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "aca-mi-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ManagedIdentity/userAssignedIdentities"
#           },
#           {
#             "actionName": "listSecrets",
#             "apiVersion": "2023-05-01-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/subscriptions/openai-subscription",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm/openai-subscription",
#             "resourceType": "Microsoft.ApiManagement/service/subscriptions"
#           },
#           {
#             "apiVersion": "2020-02-02",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Insights/components/insights-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "insights-rzyeftgva7kgm",
#             "resourceType": "Microsoft.Insights/components"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.App/containerApps/aca-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "aca-rzyeftgva7kgm",
#         "resourceType": "Microsoft.App/containerApps"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai1-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "openai1-rzyeftgva7kgm",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai1-rzyeftgva7kgm/deployments/gpt-35-turbo",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "openai1-rzyeftgva7kgm/gpt-35-turbo",
#         "resourceType": "Microsoft.CognitiveServices/accounts/deployments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai2-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "openai2-rzyeftgva7kgm",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai2-rzyeftgva7kgm/deployments/gpt-35-turbo",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "openai2-rzyeftgva7kgm/gpt-35-turbo",
#         "resourceType": "Microsoft.CognitiveServices/accounts/deployments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai1-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "openai1-rzyeftgva7kgm",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2023-05-01-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai1-rzyeftgva7kgm/providers/Microsoft.Authorization/roleAssignments/ac0f6f19-7e16-5896-86f2-55cdb46788b5",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "ac0f6f19-7e16-5896-86f2-55cdb46788b5",
#         "resourceType": "Microsoft.Authorization/roleAssignments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai2-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "openai2-rzyeftgva7kgm",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2023-05-01-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai2-rzyeftgva7kgm/providers/Microsoft.Authorization/roleAssignments/a9b4b490-89a4-52a5-93a9-4ae4e05e171a",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "a9b4b490-89a4-52a5-93a9-4ae4e05e171a",
#         "resourceType": "Microsoft.Authorization/roleAssignments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai1-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "openai1-rzyeftgva7kgm",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2021-10-01",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai1-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "openai1-rzyeftgva7kgm",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/backends/openai1",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "apim-rzyeftgva7kgm/openai1",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "apim-rzyeftgva7kgm",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai2-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "openai2-rzyeftgva7kgm",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2021-10-01",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai2-rzyeftgva7kgm",
#             "resourceGroup": "aip-pevo2-prompt-flow",
#             "resourceName": "openai2-rzyeftgva7kgm",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/backends/openai2",
#         "resourceGroup": "aip-pevo2-prompt-flow",
#         "resourceName": "apim-rzyeftgva7kgm/openai2",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       }
#     ],
#     "duration": "PT3M15.278728S",
#     "error": null,
#     "mode": "Incremental",
#     "onErrorDeployment": null,
#     "outputResources": [
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/basic-chat",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/basic-chat/diagnostics/applicationinsights",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/openai",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/openai/diagnostics/applicationinsights",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/apis/openai/policies/policy",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/backends/openai1",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/backends/openai2",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/backends/openai-backend-pool",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/loggers/apim-logger",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ApiManagement/service/apim-rzyeftgva7kgm/subscriptions/openai-subscription",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.App/containerApps/aca-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.App/managedEnvironments/acaenv-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Authorization/roleAssignments/68fc0112-cea1-54ee-b8d2-df0df6727501",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai1-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai1-rzyeftgva7kgm/deployments/gpt-35-turbo",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai1-rzyeftgva7kgm/providers/Microsoft.Authorization/roleAssignments/ac0f6f19-7e16-5896-86f2-55cdb46788b5",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai2-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai2-rzyeftgva7kgm/deployments/gpt-35-turbo",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.CognitiveServices/accounts/openai2-rzyeftgva7kgm/providers/Microsoft.Authorization/roleAssignments/a9b4b490-89a4-52a5-93a9-4ae4e05e171a",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ContainerRegistry/registries/registryrzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Insights/components/insights-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.KeyVault/vaults/keyvault-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.KeyVault/vaults/keyvault-rzyeftgva7kgm/accessPolicies/add",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/hub-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/hub-rzyeftgva7kgm/connections/open_ai_connection",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/project-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.ManagedIdentity/userAssignedIdentities/aca-mi-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.OperationalInsights/workspaces/workspace-rzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/blobServices/default",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/blobServices/default/containers/default",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/fileServices/default",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/queueServices/default",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/queueServices/default/queues/default",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.Storage/storageAccounts/storagerzyeftgva7kgm/tableServices/default",
#         "resourceGroup": "aip-pevo2-prompt-flow"
#       }
#     ],
#     "outputs": {
#       "apimResourceGatewayURL": {
#         "type": "String",
#         "value": "https://apim-rzyeftgva7kgm.azure-api.net"
#       },
#       "apimServiceId": {
#         "type": "String",
# ...
#       "openAIBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI endpoints"
#       },
#       "openAIBackendPoolName": {
#         "type": "String",
#         "value": "openai-backend-pool"
#       },
#       "openAIConfig": {
#         "type": "Array",
#         "value": [
#           {
#             "location": "swedencentral",
#             "name": "openai1"
#           },
#           {
#             "location": "francecentral",
#             "name": "openai2"
#           }
#         ]
#       },
#       "openAIDeploymentName": {
#         "type": "String",
#         "value": "gpt-35-turbo"
#       },
#       "openAIModelCapacity": {
#         "type": "Int",
#         "value": 20
#       },
#       "openAIModelName": {
#         "type": "String",
#         "value": "gpt-35-turbo"
#       },
#       "openAIModelVersion": {
#         "type": "String",
#         "value": "0613"
#       },
#       "openAISku": {
#         "type": "String",
#         "value": "S0"
#       },
#       "openAISubscriptionDescription": {
#         "type": "String",
#         "value": "OpenAI Subscription"
#       },
#       "openAISubscriptionName": {
#         "type": "String",
#         "value": "openai-subscription"
#       },
#       "promptFlowAPIDescription": {
#         "type": "String",
#         "value": "Prompt flow API"
#       },
#       "promptFlowAPIName": {
#         "type": "String",
#         "value": "basic-chat"
#       },
#       "promptFlowAPIPath": {
#         "type": "String",
#         "value": "basic-chat"
#       },
#       "promptFlowDisplayName": {
#         "type": "String",
#         "value": "basic-chat"
#       },
#       "storageAccountLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "storageAccountName": {
#         "type": "String",
#         "value": "storage"
#       }
#     },
#     "parametersLink": null,
#     "providers": [
#       {
#         "id": null,
#         "namespace": "Microsoft.Storage",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "storageAccounts/blobServices/containers",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "storageAccounts/queueServices/queues",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "storageAccounts/blobServices",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "storageAccounts/fileServices",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "storageAccounts/queueServices",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "storageAccounts/tableServices",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "storageAccounts",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.MachineLearningServices",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "workspaces/connections",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "workspaces",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.ApiManagement",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "service",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis/policies",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/backends",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/subscriptions",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/loggers",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis/diagnostics",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.OperationalInsights",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "workspaces",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Insights",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "components",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.KeyVault",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "vaults",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "vaults/accessPolicies",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.ContainerRegistry",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "registries",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.App",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "managedEnvironments",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "containerApps",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.ManagedIdentity",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "userAssignedIdentities",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Authorization",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "roleAssignments",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.CognitiveServices",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "swedencentral",
#               "francecentral"
#             ],
#             "properties": null,
#             "resourceType": "accounts",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "accounts/deployments",
#             "zoneMappings": null
#           }
#         ]
#       }
#     ],
#     "provisioningState": "Succeeded",
#     "templateHash": "16513450140948539658",
#     "templateLink": null,
#     "timestamp": "2024-10-25T21:31:24.607500+00:00",
#     "validatedResources": null
#   },
#   "resourceGroup": "aip-pevo2-prompt-flow",
#   "tags": null,
#   "type": "Microsoft.Resources/deployments"
# }
# ✅ bicep based deployment done ⌚  2024-10-25T23:31:43.114673

# %% [markdown]
# <a id='3'></a>
# ### 3️⃣ Get the deployment outputs

# %%
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimSubscriptionKey.value -o tsv
apim_subscription_key = deployment_stdout.n
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimResourceGatewayURL.value -o tsv
apim_resource_gateway_url = deployment_stdout.n
print("👉🏻 API Gateway URL: ", apim_resource_gateway_url)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.logAnalyticsWorkspaceId.value -o tsv
workspace_id = deployment_stdout.n
print("👉🏻 Workspace ID: ", workspace_id)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.applicationInsightsAppId.value -o tsv
app_id = deployment_stdout.n
print("👉🏻 App ID: ", app_id)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.projectName.value -o tsv
ml_project_name = deployment_stdout.n
print("👉🏻 Project Name: ", ml_project_name)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.projectId.value -o tsv
ml_project_id = deployment_stdout.n
print("👉🏻 Project Id: ", ml_project_id)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.containerAppResourceName.value -o tsv
containerapp_resource_name = deployment_stdout.n
print("👉🏻 Container App Name: ", containerapp_resource_name)

print(datetime.datetime.now().isoformat())
# Out:
# 👉🏻 API Gateway URL:  https://apim-rzyeftgva7kgm.azure-api.net
# 👉🏻 Workspace ID:  8fa63060-0e66-480c-bd37-0b375de7b425
# 👉🏻 App ID:  5d1f9146-713e-4afa-ac42-61c25906a489
# 👉🏻 Project Name:  project-rzyeftgva7kgm
# 👉🏻 Project Id:  /subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aip-pevo2-prompt-flow/providers/Microsoft.MachineLearningServices/workspaces/project-rzyeftgva7kgm
# 👉🏻 Container App Name:  aca-rzyeftgva7kgm
# 2024-10-25T23:35:04.506208

# %% [markdown]
# <a id='4'></a>
# ### 4️⃣ Enable Prompt Flow tracing (optional)
#
# Prompt flow [tracing feature](https://microsoft.github.io/promptflow/how-to-guides/tracing/index.html) enables users to trace LLM calls, functions and even LLM frameworks. Besides, with promptflow[azure] installed, prompt flow can also log traces to an Azure ML workspace or Azure AI project, which makes it possible to share traces with your team members.

# %%
! pf config set trace.destination=azureml:/{ml_project_id}

# %% [markdown]
# <a id='5'></a>
# ### 5️⃣ Update the connection with APIM Gateway URL and APIM Subscription Key
#
# Notes:
# - In this lab we will use the local basic-chat flow. Explore other sample flows from this [repo](https://github.com/microsoft/promptflow/tree/main/examples/flows/chat).
# - Use the [VS Code Extension](https://marketplace.visualstudio.com/items?itemName=prompt-flow.prompt-flow) to build your own flows. Follow this [guide](https://microsoft.github.io/promptflow/how-to-guides/develop-a-dag-flow/index.html) to get started.

# %%
! pf connection create --file ./{flow_name}/azure_openai.yaml --set api_key={apim_subscription_key} api_base={apim_resource_gateway_url} --name open_ai_connection
# Out:
# {
#     "auth_mode": "key",
#     "name": "open_ai_connection",
#     "module": "promptflow.connections",
#     "created_date": "2024-10-25T23:35:13.742973",
#     "last_modified_date": "2024-10-25T23:35:13.742973",
#     "type": "azure_open_ai",
#     "api_key": "******",
#     "api_base": "https://apim-rzyeftgva7kgm.azure-api.net",
#     "api_type": "azure",
#     "api_version": "2024-02-01"
# }

# %% [markdown]
# <a id='localtest'></a>
# ### 🧪 Test the Flow locally

# %%
! pf flow test --flow {flow_name} --inputs question="What's OpenAI?"
# Out:
# Starting prompt flow service...
# Start prompt flow service on 127.0.0.1:23333, version: 1.16.1.
# You can stop the prompt flow service with the following command:'pf service stop'.
#
# 2024-10-25 23:35:22 +0200  968056 execution.flow     INFO     Start executing nodes in thread pool mode.
# 2024-10-25 23:35:22 +0200  968056 execution.flow     INFO     Start to run 1 nodes with concurrency level 16.
# 2024-10-25 23:35:22 +0200  968056 execution.flow     INFO     Executing node chat. node run id: f1941dc3-dc08-42e6-8875-b62b731f025a_chat_0
# 2024-10-25 23:35:26 +0200  968056 execution.flow     INFO     Node chat completes.
# You can view the trace detail from the following URL:
# http://127.0.0.1:23333/v1.0/ui/traces/?#collection=basic-chat&uiTraceId=0x5844b71f59e59e244c3efeb4cf94a255
# {
#     "answer": "OpenAI is an artificial intelligence research laboratory and company. It was founded in December 2015 with the goal of advancing and promoting friendly AI that benefits all of humanity. OpenAI conducts research in various areas of AI, including natural language processing, reinforcement learning, robotics, and more. They also develop and release AI models and tools to help facilitate the development of AI technology. OpenAI aims to ensure that AI is used for the benefit of all and to avoid its harmful consequences."
# }

# %% [markdown]
# <a id='6'></a>
# ### 6️⃣ Create the Flow in the AI Studio Project (optional)
#
# This feature is useful for sharing the flow with other users and leveraging the capabilities of Azure AI Studio. Open the [docs](https://microsoft.github.io/promptflow/cloud/azureai/manage-flows.html#create-a-flow) to learn more.

# %%
! pfazure flow create --flow {flow_name} --set display_name={flow_name} type=chat description="Basic Chat Flow" -g {resource_group_name} -w {ml_project_name}
# Out:
# Traceback (most recent call last):
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/bin/pfazure", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/azure/_cli/entry.py", line 134, in main
#     entry(command_args)
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/azure/_cli/entry.py", line 115, in entry
#     cli_exception_and_telemetry_handler(run_command, activity_name, custom_dimensions)(args)
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/_cli/_utils.py", line 276, in wrapper
#     raise e
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/_cli/_utils.py", line 264, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/azure/_cli/entry.py", line 60, in run_command
#     raise ex
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/azure/_cli/entry.py", line 50, in run_command
#     dispatch_flow_commands(args)
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/azure/_cli/_flow.py", line 210, in dispatch_flow_commands
#     create_flow(args)
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/azure/_cli/_flow.py", line 228, in create_flow
#     pf.flows.create_or_update(flow=args.flow, **params)
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/_sdk/_telemetry/activity.py", line 265, in wrapper
#     return f(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/azure/operations/_flow_operations.py", line 142, in create_or_update
#     file_share_flow_path = self._resolve_flow_code_and_upload_to_file_share(flow=azure_flow)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/azure/operations/_flow_operations.py", line 294, in _resolve_flow_code_and_upload_to_file_share
#     storage_client = FlowFileStorageClient(
#                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/promptflow/azure/operations/_fileshare_storeage_helper.py", line 50, in __init__
#     self.directory_client.create_directory()
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/azure/core/tracing/decorator.py", line 94, in wrapper_use_tracer
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/azure/storage/fileshare/_directory_client.py", line 370, in create_directory
#     process_storage_error(error)
#   File "/home/per/azdevops/pevosdcgm/AI-Gateway/.venv/lib/python3.12/site-packages/azure/storage/fileshare/_shared/response_handlers.py", line 186, in process_storage_error
#     exec("raise error from None")   # pylint: disable=exec-used # nosec
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# azure.core.exceptions.HttpResponseError: This request is not authorized to perform this operation.
# RequestId:cf20c42b-901a-006f-532a-2722ba000000
# Time:2024-10-25T22:07:23.4483012Z
# ErrorCode:AuthorizationFailure
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>AuthorizationFailure</Code><Message>This request is not authorized to perform this operation.
# RequestId:cf20c42b-901a-006f-532a-2722ba000000
# Time:2024-10-25T22:07:23.4483012Z</Message></Error>

# %% [markdown]
# <a id='7'></a>
# ### 7️⃣ Build the Flow in the Docker format
#
# This step will generate a build folder with a Dockerfile and prompt flow artifacts. Open the [docs](https://microsoft.github.io/promptflow/how-to-guides/deploy-a-flow/deploy-using-docker.html) to learn more.

# %%
! pf flow build --source {flow_name} --output build --format docker

# %% [markdown]
# <a id='8'></a>
# ### 8️⃣ Deploy the Flow to an Azure Container App
#
# Note ⚠️: If the command fails inside this notebook, please run it in a separate terminal.

# %%
! echo az containerapp up --name {containerapp_resource_name} --source build --browse
! az containerapp up --name {containerapp_resource_name} --source build

# %% [markdown]
# <a id='requests'></a>
# ### 🧪 Test the Flow through APIM

# %%
import uuid
UUID = str(uuid.uuid4())
print(f"Request-Id: {UUID} - use this ID to trace the requests in Azure Application Insights.")

response = requests.post(apim_resource_gateway_url + "/" + flow_name + "/score", headers = {'api-key':apim_subscription_key, "Request-Id": UUID}, json = {"question": "Which is the biggest football club in Portugal?"})
if (response.status_code == 200):
    data = json.loads(response.text)
    print("💬 ", data.get("answer"))
else:
    print(response.text)

# %% [markdown]
# <a id='portal'></a>
# ### 🔍 Analyze Application Insights transactions
#
# Open the Application Insights resource in the Azure Portal and search for the Request-Id generated in the previous step.
# You can also search for the prompt flow execution, although end-to-end correlation is not yet available.
#
# ![result](result.png)

# %% [markdown]
# <a id='clean'></a>
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.
# Use the [clean-up-resources notebook](clean-up-resources.ipynb) for that.
