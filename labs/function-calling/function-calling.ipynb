# %% [markdown]
# # APIM ❤️ OpenAI
#
# ## Function calling lab
# ![flow](../../images/function-calling.gif)
#
# Playground to try the OpenAI [function calling](https://learn.microsoft.com/en-us/azure/ai-services/openai/how-to/function-calling?tabs=non-streaming%2Cpython) feature with an Azure Functions API also managed with APIM.
#
# At a high level you can break down working with functions into three steps:
# 1. Call the chat completions API with your functions and the user’s input
# 2. Use the model’s response to call your API or function
# 3. Call the chat completions API again, including the response from your function to get a final response
#
# ### Result
# ![result](result.png)
#
# ### TOC
# - [0️⃣ Initialize notebook variables](#0)
# - [1️⃣ Create the Azure Resource Group](#1)
# - [2️⃣ Create deployment using 🦾 Bicep](#2)
# - [3️⃣ Get the deployment outputs](#3)
# - [4️⃣ Deploy the function](#4)
# - [🧪 Test the Function API](#function)
# - [🧪 Test OpenAI function calling](#functioncalling)
# - [🗑️ Clean up resources](#clean)
#
# ### Prerequisites
# - [Python 3.8 or later version](https://www.python.org/) installed
# - [Pandas Library](https://pandas.pydata.org/) installed
# - [VS Code](https://code.visualstudio.com/) installed with the [Jupyter notebook extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) enabled
# - [Azure CLI](https://learn.microsoft.com/en-us/cli/azure/install-azure-cli) installed
# - [Azure Functions Core Tools](https://learn.microsoft.com/en-us/azure/azure-functions/functions-run-local?tabs=windows%2Cisolated-process%2Cnode-v4%2Cpython-v2%2Chttp-trigger%2Ccontainer-apps&pivots=programming-language-python#install-the-azure-functions-core-tools) installed
# - [An Azure Subscription](https://azure.microsoft.com/en-us/free/) with Contributor permissions
# - [Access granted to Azure OpenAI](https://aka.ms/oai/access) or just enable the mock service
# - [Sign in to Azure with Azure CLI](https://learn.microsoft.com/en-us/cli/azure/authenticate-azure-cli-interactively)

# %% [markdown]
# <a id='0'></a>
# ### 0️⃣ Initialize notebook variables
#
# - Resources will be suffixed by a unique string based on your subscription id
# - The ```mock_webapps``` variable sets the list of deployed Web Apps for the mocking functionality. Clean the ```openai_resources``` list to simulate the OpenAI behaviour with the mocking service.
# - Adjust the location parameters according your preferences and on the [product availability by Azure region.](https://azure.microsoft.com/en-us/explore/global-infrastructure/products-by-region/?cdn=disable&products=cognitive-services,api-management)
# - Adjust the OpenAI model and version according the [availability by region.](https://learn.microsoft.com/en-us/azure/ai-services/openai/concepts/models)

# %%
import os
import json
import datetime
import requests

lab_prefix="aif-pevo-"
tool_prefix="st-pevo1-"
deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
resource_group_name = f"{lab_prefix}{deployment_name}" # change the name to match your naming style
resource_group_location = "westeurope"
apim_resource_name = "apim"
apim_resource_location = "westeurope"
#apim_resource_sku = "Basicv2"
apim_resource_sku = "Consumption" 
openai_resources = [ {"name": "openai1", "location": "swedencentral"} ] # list of OpenAI resources to deploy. Clear this list to use only the mock resources
openai_resources_sku = "S0"
openai_model_name = "gpt-35-turbo"
openai_model_version = "1106"
openai_deployment_name = "gpt-35-turbo"
openai_api_version = "2024-03-01-preview"
openai_specification_url='https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/2024-02-01/inference.json'
openai_backend_pool = "openai-backend-pool"
mock_backend_pool = "mock-backend-pool"
mock_webapps = [ ]

log_analytics_name = lab_prefix + "workspace"
app_insights_name = lab_prefix + 'insights'

function_app_name = lab_prefix + "function"
#storage_account_name = (lab_prefix + "storage").replace('-','')[:20]
storage_account_name='storage'
print("storage_account_name",storage_account_name)
# Out:
# storage_account_name storage

# %% [markdown]
# <a id='1'></a>
# ### 1️⃣ Create the Azure Resource Group
# All resources deployed in this lab will be created in the specified resource group. Skip this step if you want to use an existing resource group.

# %%
resource_group_stdout = ! az group create --name {resource_group_name} --location {resource_group_location}
if resource_group_stdout.n.startswith("ERROR"):
    print(resource_group_stdout)
else:
    print("✅ Azure Resource Group ", resource_group_name, " created ⌚ ", datetime.datetime.now().time())
# Out:
# ✅ Azure Resource Group  aif-pevo-function-calling  created ⌚  16:11:07.237222

# %% [markdown]
# <a id='2'></a>
# ### 2️⃣ Create deployment using 🦾 Bicep
#
# This lab uses [Bicep](https://learn.microsoft.com/en-us/azure/azure-resource-manager/bicep/overview?tabs=bicep) to declarative define all the resources that will be deployed. Change the parameters or the [main.bicep](main.bicep) directly to try different configurations.

# %%
if len(openai_resources) > 0:
    backend_id = openai_backend_pool if len(openai_resources) > 1 else openai_resources[0].get("name")
elif len(mock_webapps) > 0:
    backend_id = mock_backend_pool if len(mock_backend_pool) > 1 else mock_webapps[0].get("name")

with open("policy.xml", 'r') as policy_xml_file:
    policy_template_xml = policy_xml_file.read()
    policy_xml = policy_template_xml.replace("{backend-id}", backend_id)
    policy_xml_file.close()
open("policy.xml", 'w').write(policy_xml)

bicep_parameters = {
  "$schema": "https://schema.management.azure.com/schemas/2019-04-01/deploymentParameters.json#",
  "contentVersion": "1.0.0.0",
  "parameters": {
    "mockWebApps": { "value": mock_webapps },
    "mockBackendPoolName": { "value": mock_backend_pool },
    "openAIBackendPoolName": { "value": openai_backend_pool },
    "openAIConfig": { "value": openai_resources },
    "openAIDeploymentName": { "value": openai_deployment_name },
    "openAISku": { "value": openai_resources_sku },
    "openAIModelName": { "value": openai_model_name },
    "openAIModelVersion": { "value": openai_model_version },
    "openAIAPISpecURL": { "value": openai_specification_url },
    "apimResourceName": { "value": apim_resource_name},
    "apimResourceLocation": { "value": apim_resource_location},
    "apimSku": { "value": apim_resource_sku},
    "logAnalyticsName": { "value": log_analytics_name },
    "applicationInsightsName": { "value": app_insights_name },
    "functionAppName": { "value": function_app_name },
    "storageAccountName": { "value": storage_account_name }
  }
}
with open('params.json', 'w') as bicep_parameters_file:
    bicep_parameters_file.write(json.dumps(bicep_parameters))

! az deployment group create --name {deployment_name} --resource-group {resource_group_name} --template-file "main.bicep" --parameters "params.json"

open("policy.xml", 'w').write(policy_template_xml)
# Out:
# {
#   "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Resources/deployments/function-calling",
#   "location": null,
#   "name": "function-calling",
#   "properties": {
#     "correlationId": "461c9e98-5e21-4396-861a-9ff806985964",
#     "debugSetting": null,
#     "dependencies": [
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "apim-m4z5osvxasqhi",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/apis/openai",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "apim-m4z5osvxasqhi/openai",
#         "resourceType": "Microsoft.ApiManagement/service/apis"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/apis/openai",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "apim-m4z5osvxasqhi/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/apis/openai/policies/policy",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "apim-m4z5osvxasqhi/openai/policy",
#         "resourceType": "Microsoft.ApiManagement/service/apis/policies"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "apim-m4z5osvxasqhi",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/subscriptions/openai-subscription",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "apim-m4z5osvxasqhi/openai-subscription",
#         "resourceType": "Microsoft.ApiManagement/service/subscriptions"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.OperationalInsights/workspaces/aif-pevo-workspace-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "aif-pevo-workspace-m4z5osvxasqhi",
#             "resourceType": "Microsoft.OperationalInsights/workspaces"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Insights/components/aif-pevo-insights-m4z5osvxasqhi",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "aif-pevo-insights-m4z5osvxasqhi",
#         "resourceType": "Microsoft.Insights/components"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "apim-m4z5osvxasqhi",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Insights/components/aif-pevo-insights-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "aif-pevo-insights-m4z5osvxasqhi",
#             "resourceType": "Microsoft.Insights/components"
#           },
#           {
#             "apiVersion": "2020-02-02",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Insights/components/aif-pevo-insights-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "aif-pevo-insights-m4z5osvxasqhi",
#             "resourceType": "Microsoft.Insights/components"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/loggers/apim-logger",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "apim-m4z5osvxasqhi/apim-logger",
#         "resourceType": "Microsoft.ApiManagement/service/loggers"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/apis/openai",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "apim-m4z5osvxasqhi/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/loggers/apim-logger",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "apim-m4z5osvxasqhi/apim-logger",
#             "resourceType": "Microsoft.ApiManagement/service/loggers"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/apis/openai/diagnostics/applicationinsights",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "apim-m4z5osvxasqhi/openai/applicationinsights",
#         "resourceType": "Microsoft.ApiManagement/service/apis/diagnostics"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Insights/components/aif-pevo-insights-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "aif-pevo-insights-m4z5osvxasqhi",
#             "resourceType": "Microsoft.Insights/components"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Insights/workbooks/626d96b0-4ef7-5676-89b9-b0d15339a57e",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "626d96b0-4ef7-5676-89b9-b0d15339a57e",
#         "resourceType": "Microsoft.Insights/workbooks"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Insights/components/aif-pevo-insights-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "aif-pevo-insights-m4z5osvxasqhi",
#             "resourceType": "Microsoft.Insights/components"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Web/serverfarms/aif-pevo-function-asp-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "aif-pevo-function-asp-m4z5osvxasqhi",
#             "resourceType": "Microsoft.Web/serverfarms"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Storage/storageAccounts/storagem4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "storagem4z5osvxasqhi",
#             "resourceType": "Microsoft.Storage/storageAccounts"
#           },
#           {
#             "actionName": "listKeys",
#             "apiVersion": "2023-01-01",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Storage/storageAccounts/storagem4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "storagem4z5osvxasqhi",
#             "resourceType": "Microsoft.Storage/storageAccounts"
#           },
#           {
#             "apiVersion": "2020-02-02",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Insights/components/aif-pevo-insights-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "aif-pevo-insights-m4z5osvxasqhi",
#             "resourceType": "Microsoft.Insights/components"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Web/sites/aif-pevo-function-m4z5osvxasqhi",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "aif-pevo-function-m4z5osvxasqhi",
#         "resourceType": "Microsoft.Web/sites"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "apim-m4z5osvxasqhi",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Web/sites/aif-pevo-function-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "aif-pevo-function-m4z5osvxasqhi",
#             "resourceType": "Microsoft.Web/sites"
#           },
#           {
#             "apiVersion": "2022-09-01",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Web/sites/aif-pevo-function-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "aif-pevo-function-m4z5osvxasqhi",
#             "resourceType": "Microsoft.Web/sites"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/apis/weather",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "apim-m4z5osvxasqhi/weather",
#         "resourceType": "Microsoft.ApiManagement/service/apis"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.CognitiveServices/accounts/openai1-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "openai1-m4z5osvxasqhi",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.CognitiveServices/accounts/openai1-m4z5osvxasqhi/deployments/gpt-35-turbo",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "openai1-m4z5osvxasqhi/gpt-35-turbo",
#         "resourceType": "Microsoft.CognitiveServices/accounts/deployments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "apim-m4z5osvxasqhi",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.CognitiveServices/accounts/openai1-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "openai1-m4z5osvxasqhi",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2023-05-01-preview",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "apim-m4z5osvxasqhi",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.CognitiveServices/accounts/openai1-m4z5osvxasqhi/providers/Microsoft.Authorization/roleAssignments/4fc18259-eb08-580f-a900-01dcd095d94b",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "4fc18259-eb08-580f-a900-01dcd095d94b",
#         "resourceType": "Microsoft.Authorization/roleAssignments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "apim-m4z5osvxasqhi",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.CognitiveServices/accounts/openai1-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "openai1-m4z5osvxasqhi",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2021-10-01",
#             "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.CognitiveServices/accounts/openai1-m4z5osvxasqhi",
#             "resourceGroup": "aif-pevo-function-calling",
#             "resourceName": "openai1-m4z5osvxasqhi",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/backends/openai1",
#         "resourceGroup": "aif-pevo-function-calling",
#         "resourceName": "apim-m4z5osvxasqhi/openai1",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       }
#     ],
#     "duration": "PT1M47.9979718S",
#     "error": null,
#     "mode": "Incremental",
#     "onErrorDeployment": null,
#     "outputResources": [
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/apis/openai",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/apis/openai/diagnostics/applicationinsights",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/apis/openai/policies/policy",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/apis/weather",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/backends/openai1",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/loggers/apim-logger",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi/subscriptions/openai-subscription",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.CognitiveServices/accounts/openai1-m4z5osvxasqhi",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.CognitiveServices/accounts/openai1-m4z5osvxasqhi/deployments/gpt-35-turbo",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.CognitiveServices/accounts/openai1-m4z5osvxasqhi/providers/Microsoft.Authorization/roleAssignments/4fc18259-eb08-580f-a900-01dcd095d94b",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Insights/components/aif-pevo-insights-m4z5osvxasqhi",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Insights/workbooks/626d96b0-4ef7-5676-89b9-b0d15339a57e",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.OperationalInsights/workspaces/aif-pevo-workspace-m4z5osvxasqhi",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Storage/storageAccounts/storagem4z5osvxasqhi",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Web/serverfarms/aif-pevo-function-asp-m4z5osvxasqhi",
#         "resourceGroup": "aif-pevo-function-calling"
#       },
#       {
#         "id": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.Web/sites/aif-pevo-function-m4z5osvxasqhi",
#         "resourceGroup": "aif-pevo-function-calling"
#       }
#     ],
#     "outputs": {
#       "apimResourceGatewayURL": {
#         "type": "String",
#         "value": "https://apim-m4z5osvxasqhi.azure-api.net"
#       },
#       "apimServiceId": {
#         "type": "String",
#         "value": "/subscriptions/a46c2e68-1def-41bf-b7dd-c8ec765e3367/resourceGroups/aif-pevo-function-calling/providers/Microsoft.ApiManagement/service/apim-m4z5osvxasqhi"
#       },
#       "apimSubscriptionKey": {
#         "type": "String",
#         "value": "5e085ae8022e4bd6b9c47f2d9ef67096"
#       },
#       "applicationInsightsAppId": {
#         "type": "String",
#         "value": "ace8f669-c816-434a-9e38-ba8be98665d3"
#       },
#       "functionAppResourceName": {
#         "type": "String",
#         "value": "aif-pevo-function-m4z5osvxasqhi"
#       },
#       "logAnalyticsWorkspaceId": {
#         "type": "String",
#         "value": "fa716c7b-d3f0-40ce-8857-7ba5db4060c9"
#       }
#     },
#     "parameters": {
#       "apiDiagnosticsLogBytes": {
#         "type": "Int",
#         "value": 8192
#       },
#       "apimLoggerDescription": {
#         "type": "String",
#         "value": "APIM Logger for OpenAI API"
#       },
#       "apimLoggerName": {
#         "type": "String",
#         "value": "apim-logger"
#       },
#       "apimPublisherEmail": {
#         "type": "String",
#         "value": "noreply@microsoft.com"
#       },
#       "apimPublisherName": {
#         "type": "String",
#         "value": "Microsoft"
#       },
#       "apimResourceLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "apimResourceName": {
#         "type": "String",
#         "value": "apim"
#       },
#       "apimSku": {
#         "type": "String",
#         "value": "Consumption"
#       },
#       "apimSkuCount": {
#         "type": "Int",
#         "value": 1
#       },
#       "applicationInsightsLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "applicationInsightsName": {
#         "type": "String",
#         "value": "aif-pevo-insights"
#       },
#       "functionAPIDescription": {
#         "type": "String",
#         "value": "Weather API"
#       },
#       "functionAPIDisplayName": {
#         "type": "String",
#         "value": "WeatherAPI"
#       },
#       "functionAPIName": {
#         "type": "String",
#         "value": "weather"
#       },
#       "functionAPIPath": {
#         "type": "String",
#         "value": "weather"
#       },
#       "functionAppLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "functionAppName": {
#         "type": "String",
#         "value": "aif-pevo-function"
#       },
#       "functionName": {
#         "type": "String",
#         "value": "WeatherHttpTrigger"
#       },
#       "logAnalyticsLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "logAnalyticsName": {
#         "type": "String",
#         "value": "aif-pevo-workspace"
#       },
#       "mockBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI Mocking endpoints"
#       },
#       "mockBackendPoolName": {
#         "type": "String",
#         "value": "mock-backend-pool"
#       },
#       "mockWebApps": {
#         "type": "Array",
#         "value": []
#       },
#       "openAIAPIDescription": {
#         "type": "String",
#         "value": "Azure OpenAI API inferencing API"
#       },
#       "openAIAPIDisplayName": {
#         "type": "String",
#         "value": "OpenAI"
#       },
#       "openAIAPIName": {
#         "type": "String",
#         "value": "openai"
#       },
#       "openAIAPIPath": {
#         "type": "String",
#         "value": "openai"
#       },
#       "openAIAPISpecURL": {
#         "type": "String",
#         "value": "https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/2024-02-01/inference.json"
#       },
#       "openAIBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI endpoints"
#       },
#       "openAIBackendPoolName": {
#         "type": "String",
#         "value": "openai-backend-pool"
#       },
#       "openAIConfig": {
#         "type": "Array",
#         "value": [
#           {
#             "location": "swedencentral",
#             "name": "openai1"
#           }
#         ]
#       },
#       "openAIDeploymentName": {
#         "type": "String",
#         "value": "gpt-35-turbo"
#       },
#       "openAIModelCapacity": {
#         "type": "Int",
#         "value": 20
#       },
#       "openAIModelName": {
#         "type": "String",
#         "value": "gpt-35-turbo"
#       },
#       "openAIModelVersion": {
#         "type": "String",
#         "value": "1106"
#       },
#       "openAISku": {
#         "type": "String",
#         "value": "S0"
#       },
#       "openAISubscriptionDescription": {
#         "type": "String",
#         "value": "OpenAI Subscription"
#       },
#       "openAISubscriptionName": {
#         "type": "String",
#         "value": "openai-subscription"
#       },
#       "storageAccountLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "storageAccountName": {
#         "type": "String",
#         "value": "storage"
#       },
#       "storageAccountType": {
#         "type": "String",
#         "value": "Standard_LRS"
#       },
#       "workbookDisplayName": {
#         "type": "String",
#         "value": "OpenAI Usage Analysis"
#       },
#       "workbookLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "workbookName": {
#         "type": "String",
#         "value": "OpenAIUsageAnalysis"
#       }
#     },
#     "parametersLink": null,
#     "providers": [
#       {
#         "id": null,
#         "namespace": "Microsoft.ApiManagement",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "service",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis/policies",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/subscriptions",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/loggers",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis/diagnostics",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/backends",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.OperationalInsights",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "workspaces",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Insights",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "components",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "workbooks",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Storage",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "storageAccounts",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Web",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "serverfarms",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "sites",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.CognitiveServices",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "swedencentral"
#             ],
#             "properties": null,
#             "resourceType": "accounts",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "accounts/deployments",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Authorization",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "roleAssignments",
#             "zoneMappings": null
#           }
#         ]
#       }
#     ],
#     "provisioningState": "Succeeded",
#     "templateHash": "16782869215510467970",
#     "templateLink": null,
#     "timestamp": "2024-10-22T14:13:17.860532+00:00",
#     "validatedResources": null
#   },
#   "resourceGroup": "aif-pevo-function-calling",
#   "tags": null,
#   "type": "Microsoft.Resources/deployments"
# }
# WARNING: c:\Users\u3184\azdevops\pevosdcgh\AI-Gateway\labs\function-calling\main.bicep(133,7) : Warning no-unused-params: Parameter "functionName" is declared but never used. [https://aka.ms/bicep/linter/no-unused-params]
#
# c:\Users\u3184\azdevops\pevosdcgh\AI-Gateway\labs\function-calling\main.bicep(319,3) : Warning BCP035: The specified "object" declaration is missing the following required properties: "protocol", "url". If this is a resource type definition inaccuracy, report it using https://aka.ms/bicep-type-issues. [https://aka.ms/bicep/core-diagnostics#BCP035]
#
# c:\Users\u3184\azdevops\pevosdcgh\AI-Gateway\labs\function-calling\main.bicep(336,3) : Warning BCP035: The specified "object" declaration is missing the following required properties: "protocol", "url". If this is a resource type definition inaccuracy, report it using https://aka.ms/bicep-type-issues. [https://aka.ms/bicep/core-diagnostics#BCP035]
#
# c:\Users\u3184\azdevops\pevosdcgh\AI-Gateway\labs\function-calling\main.bicep(547,12) : Warning BCP036: The property "value" expected a value of type "null | string" but the provided value is of type "object". If this is a resource type definition inaccuracy, report it using https://aka.ms/bicep-type-issues. [https://aka.ms/bicep/core-diagnostics#BCP036]
# 618

# %% [markdown]
# <a id='3'></a>
# ### 3️⃣ Get the deployment outputs

# %%
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimSubscriptionKey.value -o tsv
apim_subscription_key = deployment_stdout.n
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimResourceGatewayURL.value -o tsv
apim_resource_gateway_url = deployment_stdout.n
print("👉🏻 API Gateway URL: ", apim_resource_gateway_url)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.logAnalyticsWorkspaceId.value -o tsv
workspace_id = deployment_stdout.n
print("👉🏻 Workspace ID: ", workspace_id)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.applicationInsightsAppId.value -o tsv
app_id = deployment_stdout.n
print("👉🏻 App ID: ", app_id)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.functionAppResourceName.value -o tsv
function_app_resource_name = deployment_stdout.n
print("👉🏻 Function Name: ", function_app_resource_name)

# %% [markdown]
# <a id='4'></a>
# ### 4️⃣ Deploy the function
#
# Deploy the local function project to the function app resource previously created

# %%
! func azure functionapp publish {function_app_resource_name}

# %% [markdown]
# <a id='function'></a>
# ### 🧪 Test the Function API

# %%
request = { "location": "London", "unit": "celsius" }
url = apim_resource_gateway_url + "/weather"
response = requests.post(url, headers = {'api-key':apim_subscription_key}, json = request)
if (response.status_code == 200):
    data = json.loads(response.text)
    print("location: ", data.get("location"))
    print("unit: ", data.get("unit"))
    print("temperature: ", data.get("temperature"))
else:
    print(response.text)

# %% [markdown]
# <a id='functioncalling'></a>
# ### 🧪 Test OpenAI function calling
#
# The following code was reused from the [Azure OpenAI documentation](https://learn.microsoft.com/en-us/azure/ai-services/openai/how-to/function-calling?tabs=non-streaming%2Cpython). The `UUID` will be used to search for the end-to-end transaction in Application insights.
#
# - Note: run ```pip install openai``` in a terminal before executing this step.

# %%
from openai import AzureOpenAI
import uuid

prompt = "What's the weather like in London and its big sister cities?"

UUID = str(uuid.uuid4())
print(f"Request-Id: {UUID} - use this ID to trace the requests in Azure Application Insights.")

client = AzureOpenAI(
    azure_endpoint=apim_resource_gateway_url,
    api_key=apim_subscription_key,
    api_version=openai_api_version
)

# Example function hard coded to return the same weather
# the local function calls the API
def get_current_weather(location, unit):
    request = { "location": location, "unit": unit }
    url = apim_resource_gateway_url + "/weather"
    response = requests.post(url, headers = {'api-key':apim_subscription_key, "Request-Id": UUID}, json = request)
    if (response.status_code == 200):
        return response.text
    else:
        return json.dumps({"location": location, "temperature": "unknown"})

# Step 1: send the conversation and available functions to the model
messages = [{"role": "user", "content": prompt}]
tools = [
    {
        "type": "function",
        "function": {
            "name": "get_current_weather",
            "description": "Get the current weather in a given location, using the local temperature measuring unit.",
            "parameters": {
                "type": "object",
                "properties": {
                    "location": {
                        "type": "string",
                        "description": "The city and state, e.g. San Francisco, CA",
                    },
                    "unit": {
                        "type": "string",
                        "description": "The temperature measuring unit, e.g. celsius for London or fahrenheit for US cities",
                        "enum": ["celsius", "fahrenheit"]
                    },
                },
                "required": ["location", "unit"],
            },
        },
    }
]
print("▶️ Step 1: start a completion to identify the appropriate functions to invoke based on the prompt\n", prompt)
response = client.chat.completions.create(
    model=openai_deployment_name,
    messages=messages,
    tools=tools,
    tool_choice="auto",  # auto is default, but we'll be explicit
    extra_headers = {"Request-Id": UUID}
)
response_message = response.choices[0].message
tool_calls = response_message.tool_calls
if tool_calls:
    # Step 2: call the function
    # Note: the JSON response may not always be valid; be sure to handle errors
    available_functions = {
        "get_current_weather": get_current_weather,
    }  # only one function in this example, but you can have multiple
    messages.append(response_message)  # extend conversation with assistant's reply
    # send the info for each function call and function response to the model
    print("▶️ Step 2: call the functions")
    for tool_call in tool_calls:
        function_name = tool_call.function.name
        function_to_call = available_functions[function_name]
        function_args = json.loads(tool_call.function.arguments)
        function_response = function_to_call(
            location=function_args.get("location"),
            unit=function_args.get("unit"),
        )
        print(function_response)
        messages.append(
            {
                "tool_call_id": tool_call.id,
                "role": "tool",
                "name": function_name,
                "content": function_response,
            }
        )  # extend conversation with function response
    print("▶️ Step 3: finish with a completion to anwser the user prompt using the function response")
    second_response = client.chat.completions.create(
        model=openai_deployment_name,
        messages=messages,
        extra_headers = {"Request-Id": UUID}
    )  # get a new response from the model where it can see the function response
    print(second_response.choices[0].message.content)

# %% [markdown]
# <a id='clean'></a>
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.
# Use the [clean-up-resources notebook](clean-up-resources.ipynb) for that.
